# %%
import pandas as pd

# %%
url = ["http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/01/11-15", "http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/02/11-15","http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/03/11-15","http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/04/11-15","http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/05/11-15", "http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/06/11-15", "http://rates.am/am/armenian-dram-exchange-rates/banks/non-cash/2017/06/07/11-15"]

# %%
for day in url:
    rate_am = pd.read_html(day)
    data = rate_am[2]
    print data[2:19]
# Out:
#      0                       1    2   3              4       5       6   \
# 2    1.               Արցախբանկ  NaN  24  01 Հնս, 11:15     481  484.50
# 3    2.       ՎՏԲ-Հայաստան Բանկ  NaN  68  01 Հնս, 11:15     481  483.75
# 4    3.               Ինեկոբանկ  NaN  23  01 Հնս, 11:15  480.50     484
# 5    4.             Մելլաթ բանկ  NaN   1  01 Հնս, 11:15     480     484
# 6    5.       Էյչ-Էս-Բի-Սի Բանկ  NaN   9  01 Հնս, 11:15  480.50  484.50
# 7    6.            Կոնվերս բանկ  NaN  35  01 Հնս, 11:15     480  483.50
# 8    7.  ԱԿԲԱ-ԿՐԵԴԻՏ ԱԳՐԻԿՈԼ ..  NaN  59  01 Հնս, 11:15  480.50     484
# 9    8.              Ամերիաբանկ  NaN  11  01 Հնս, 11:15  479.50  483.50
# 10   9.       ՀԱՅԲԻԶՆԵՍԲԱՆԿ ՓԲԸ  NaN  53  01 Հնս, 11:15     480  483.50
# 11  10.              ԱՐԱՐԱՏԲԱՆԿ  NaN  48  01 Հնս, 11:15  480.50     484
# 12  11.     Բիբլոս Բանկ Արմենիա  NaN   5  01 Հնս, 11:15     480     484
# 13  12.              Արդշինբանկ  NaN  53  01 Հնս, 11:15  480.50  483.50
# ...
